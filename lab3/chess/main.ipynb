# %%
import chess
import chess.engine
import time
import chess.svg
from IPython.display import SVG, display



engine = chess.engine.SimpleEngine.popen_uci(
    r"C:\Users\anton\OneDrive\Документи\KPI\3 курс\1 semester\ПІІС\piisLabs\lab3\chess\stockfish_15_win_x64_avx2\stockfish_15_x64_avx2.exe")


def stockfish_eval(board_instance, isMax):
    info = engine.analyse(board_instance, chess.engine.Limit(depth=1))


    if not isMax:
        result = chess.engine.PovScore(info['score'], chess.BLACK).pov(chess.BLACK).relative.score()
    else:
        result = chess.engine.PovScore(info['score'], chess.WHITE).pov(chess.WHITE).relative.score()
    # print(result)
    if result is None:
        result = 0
    return result



def best_move_using_negaMax(board_instance, depth):
    def negaMax(board, depth, is_max):
        if depth == 0:
            return stockfish_eval(board, is_max)

        maxValueIn = -1_000_000
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            value = -negaMax(boardCopy, depth - 1, 1 - is_max)
            if value > maxValueIn:
                maxValueIn = value
        return maxValueIn

    maxValue = -1_000_000
    bestMove = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        value = -negaMax(boardCopy, depth, 1 - boardCopy.turn)
        if value > maxValue:
            maxValue = value
            bestMove = move
    return bestMove


def best_move_using_negaScout(board_instance, depth, alpha=-999999, beta=999999):
    def negaScout(board, depthIn, alphaIn, betaIn):
        if depthIn == 0:
            return stockfish_eval(board, board.turn)
        scoreIn = -1_000_000
        n = betaIn
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            cur = -negaScout(boardCopy, depthIn - 1, -n, -alphaIn)
            if cur > scoreIn:
                if n == beta or depthIn <= 2:
                    scoreIn = cur
                else:
                    scoreIn = -negaScout(boardCopy, depthIn - 1, -betaIn, -cur)
            if scoreIn > alphaIn:
                alphaIn = scoreIn
            if alphaIn >= betaIn:
                return alphaIn
            n = alphaIn + 1
        return scoreIn

    score = -1_000_000
    n = beta
    best_move = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        cur = -negaScout(boardCopy, depth - 1, -n, -alpha)
        if cur > score:
            if n == beta or depth <= 2:
                score = cur
            else:
                score = -negaScout(boardCopy, depth - 1, -beta, -cur)
        if score > alpha:
            alpha = score
            best_move = move
        if alpha >= beta:
            return best_move
        n = alpha + 1

    return best_move


def best_move_using_pvs(board_instance, depth, alpha=-999999, beta=999999):
    def pvs(board, depthIn, alphaIn, betaIn):
        if depthIn == 0:
            return stockfish_eval(board, board.turn)
        bSearchPvIn = True
        for legal_move in board.legal_moves:
            move = chess.Move.from_uci(str(legal_move))
            boardCopy = board.copy()
            boardCopy.push(move)
            if bSearchPvIn:
                cur = -pvs(boardCopy, depthIn - 1, -betaIn, -alphaIn)
            else:
                cur = -pvs(boardCopy, depthIn - 1, -alphaIn-1, -alphaIn)
                if alphaIn < cur < betaIn:
                    cur = -pvs(boardCopy, depthIn - 1, -betaIn, -alphaIn)
            if cur >= betaIn:
                return betaIn
            if cur > alphaIn:
                alphaIn = cur
                bSearchPvIn = False

        return alphaIn

    bSearchPv = True
    best_move = None
    for legal_move in board_instance.legal_moves:
        move = chess.Move.from_uci(str(legal_move))
        boardCopy = board_instance.copy()
        boardCopy.push(move)
        if bSearchPv:
            cur = -pvs(boardCopy, depth - 1, -beta, -alpha)
        else:
            cur = -pvs(boardCopy, depth - 1, -alpha - 1, -alpha)
            if alpha < cur < beta:
                cur = -pvs(boardCopy, depth - 1, -beta, -alpha)
        if cur >= beta:
            best_move = move
            return best_move
        if cur > alpha:
            best_move = move
            alpha = cur
            bSearchPv = False

    return best_move


def game_between_two_computers_pvs(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_pvs(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_pvs(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())
        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


def game_between_two_computers_negaScout(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_negaScout(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_negaScout(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())
        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


def game_between_two_computers_negaMax(depth=1):
    board = chess.Board()
    n = 0

    while board.is_checkmate() != True and board.is_fivefold_repetition() != True and board.is_seventyfive_moves() != True:
        start = time.time()
        if n % 2 == 0:
            print("WHITE Turn")
            move = best_move_using_negaMax(board, depth)
        else:

            print("BLACK Turn")
            move = best_move_using_negaMax(board, depth)
        end = time.time()

        if move == None:
            print("GG, checkmate")
            break

        print("Move in UCI format:", move)
        print("Time taken by Move:", end - start)
        print("Moves taken:", n)
        print("FiveFold", board.is_fivefold_repetition())

        board.push(move)
        # display(SVG(chess.svg.board(board, size=400)))
        print(board)
        print("\n")
        n = n + 1
    if board.is_fivefold_repetition():
        print("GG, fivefold")


if __name__ == '__main__':
    game_between_two_computers_negaMax()
    # game_between_two_computers_negaScout()
    # game_between_two_computers_pvs()
    engine.quit()
# Out:
# WHITE Turn
# Move in UCI format: e2e4
# Time taken by Move: 0.48664212226867676
# Moves taken: 0
# FiveFold False
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: c7c6
# Time taken by Move: 1.093785047531128
# Moves taken: 1
# FiveFold False
# r n b q k b n r
# p p . p p p p p
# . . p . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: d2d4
# Time taken by Move: 0.6956751346588135
# Moves taken: 2
# FiveFold False
# r n b q k b n r
# p p . p p p p p
# . . p . . . . .
# . . . . . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: d7d5
# Time taken by Move: 0.9033606052398682
# Moves taken: 3
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . p . . . . .
# . . . p . . . .
# . . . P P . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: e4e5
# Time taken by Move: 1.230999231338501
# Moves taken: 4
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . p . . . . .
# . . . p P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: c6c5
# Time taken by Move: 1.1188247203826904
# Moves taken: 5
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . . . . . . .
# . . p p P . . .
# . . . P . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: d4c5
# Time taken by Move: 1.1618282794952393
# Moves taken: 6
# FiveFold False
# r n b q k b n r
# p p . . p p p p
# . . . . . . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# BLACK Turn
# Move in UCI format: e7e6
# Time taken by Move: 1.208357810974121
# Moves taken: 7
# FiveFold False
# r n b q k b n r
# p p . . . p p p
# . . . . p . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . . . .
# P P P . . P P P
# R N B Q K B N R
#
#
# WHITE Turn
# Move in UCI format: g1f3
# Time taken by Move: 1.347391128540039
# Moves taken: 8
# FiveFold False
# r n b q k b n r
# p p . . . p p p
# . . . . p . . .
# . . P p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
#
#
# BLACK Turn
# Move in UCI format: f8c5
# Time taken by Move: 1.2430000305175781
# Moves taken: 9
# FiveFold False
# r n b q k . n r
# p p . . . p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P . . P P P
# R N B Q K B . R
#
#
# WHITE Turn
# Move in UCI format: f1d3
# Time taken by Move: 1.5369548797607422
# Moves taken: 10
# FiveFold False
# r n b q k . n r
# p p . . . p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q K . . R
#
#
# BLACK Turn
# Move in UCI format: g8e7
# Time taken by Move: 1.5284621715545654
# Moves taken: 11
# FiveFold False
# r n b q k . . r
# p p . . n p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q K . . R
#
#
# WHITE Turn
# Move in UCI format: e1g1
# Time taken by Move: 1.5940158367156982
# Moves taken: 12
# FiveFold False
# r n b q k . . r
# p p . . n p p p
# . . . . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: b8c6
# Time taken by Move: 1.3178493976593018
# Moves taken: 13
# FiveFold False
# r . b q k . . r
# p p . . n p p p
# . . n . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P . . P P P
# R N B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: b1d2
# Time taken by Move: 1.5060110092163086
# Moves taken: 14
# FiveFold False
# r . b q k . . r
# p p . . n p p p
# . . n . p . . .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: e7g6
# Time taken by Move: 1.2620880603790283
# Moves taken: 15
# FiveFold False
# r . b q k . . r
# p p . . . p p p
# . . n . p . n .
# . . b p P . . .
# . . . . . . . .
# . . . B . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: d3g6
# Time taken by Move: 1.5136611461639404
# Moves taken: 16
# FiveFold False
# r . b q k . . r
# p p . . . p p p
# . . n . p . B .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: h7g6
# Time taken by Move: 1.2497689723968506
# Moves taken: 17
# FiveFold False
# r . b q k . . r
# p p . . . p p .
# . . n . p . p .
# . . b p P . . .
# . . . . . . . .
# . . . . . N . .
# P P P N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: c2c3
# Time taken by Move: 1.0830011367797852
# Moves taken: 18
# FiveFold False
# r . b q k . . r
# p p . . . p p .
# . . n . p . p .
# . . b p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q . R K .
#
#
# BLACK Turn
# Move in UCI format: c5e7
# Time taken by Move: 1.2464699745178223
# Moves taken: 19
# FiveFold False
# r . b q k . . r
# p p . . b p p .
# . . n . p . p .
# . . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q . R K .
#
#
# WHITE Turn
# Move in UCI format: f1e1
# Time taken by Move: 1.0153586864471436
# Moves taken: 20
# FiveFold False
# r . b q k . . r
# p p . . b p p .
# . . n . p . p .
# . . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q R . K .
#
#
# BLACK Turn
# Move in UCI format: a7a5
# Time taken by Move: 1.1876885890960693
# Moves taken: 21
# FiveFold False
# r . b q k . . r
# . p . . b p p .
# . . n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . N . P P P
# R . B Q R . K .
#
#
# WHITE Turn
# Move in UCI format: d2f1
# Time taken by Move: 1.1949708461761475
# Moves taken: 22
# FiveFold False
# r . b q k . . r
# . p . . b p p .
# . . n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B Q R N K .
#
#
# BLACK Turn
# Move in UCI format: b7b6
# Time taken by Move: 1.4381306171417236
# Moves taken: 23
# FiveFold False
# r . b q k . . r
# . . . . b p p .
# . p n . p . p .
# p . . p P . . .
# . . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B Q R N K .
#
#
# WHITE Turn
# Move in UCI format: d1a4
# Time taken by Move: 1.4393041133880615
# Moves taken: 24
# FiveFold False
# r . b q k . . r
# . . . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B . R N K .
#
#
# BLACK Turn
# Move in UCI format: c8b7
# Time taken by Move: 1.545280933380127
# Moves taken: 25
# FiveFold False
# r . . q k . . r
# . b . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . B . R N K .
#
#
# WHITE Turn
# Move in UCI format: c1e3
# Time taken by Move: 1.6028456687927246
# Moves taken: 26
# FiveFold False
# r . . q k . . r
# . b . . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . B N . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: d8c7
# Time taken by Move: 1.7634007930755615
# Moves taken: 27
# FiveFold False
# r . . . k . . r
# . b q . b p p .
# . p n . p . p .
# p . . p P . . .
# Q . . . . . . .
# . . P . B N . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: e3g5
# Time taken by Move: 2.0345816612243652
# Moves taken: 28
# FiveFold False
# r . . . k . . r
# . b q . b p p .
# . p n . p . p .
# p . . p P . B .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: e7g5
# Time taken by Move: 2.0200016498565674
# Moves taken: 29
# FiveFold False
# r . . . k . . r
# . b q . . p p .
# . p n . p . p .
# p . . p P . b .
# Q . . . . . . .
# . . P . . N . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: f3g5
# Time taken by Move: 1.8070006370544434
# Moves taken: 30
# FiveFold False
# r . . . k . . r
# . b q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . . . . .
# P P . . . P P P
# R . . . R N K .
#
#
# BLACK Turn
# Move in UCI format: b7a6
# Time taken by Move: 1.5506212711334229
# Moves taken: 31
# FiveFold False
# r . . . k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . . . . .
# P P . . . P P P
# R . . . R N K .
#
#
# WHITE Turn
# Move in UCI format: f1e3
# Time taken by Move: 1.9606144428253174
# Moves taken: 32
# FiveFold False
# r . . . k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . .
# . . P . N . . .
# P P . . . P P P
# R . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: h8h5
# Time taken by Move: 2.063274621963501
# Moves taken: 33
# FiveFold False
# r . . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . .
# . . P . N . . .
# P P . . . P P P
# R . . . R . K .
#
#
# WHITE Turn
# Move in UCI format: h2h4
# Time taken by Move: 2.2339344024658203
# Moves taken: 34
# FiveFold False
# r . . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# R . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: a8b8
# Time taken by Move: 1.8594470024108887
# Moves taken: 35
# FiveFold False
# . r . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# R . . . R . K .
#
#
# WHITE Turn
# Move in UCI format: a1d1
# Time taken by Move: 1.8909225463867188
# Moves taken: 36
# FiveFold False
# . r . . k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b8d8
# Time taken by Move: 1.725416660308838
# Moves taken: 37
# FiveFold False
# . . . r k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . . .
# P P . . . P P .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: g2g3
# Time taken by Move: 1.924886703491211
# Moves taken: 38
# FiveFold False
# . . . r k . . .
# . . q . . p p .
# b p n . p . p .
# p . . p P . N r
# Q . . . . . . P
# . . P . N . P .
# P P . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: h5h8
# Time taken by Move: 1.7823576927185059
# Moves taken: 39
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . . P
# . . P . N . P .
# P P . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: e3g4
# Time taken by Move: 1.9689998626708984
# Moves taken: 40
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# b p n . p . p .
# p . . p P . N .
# Q . . . . . N P
# . . P . . . P .
# P P . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: a6c4
# Time taken by Move: 1.7975873947143555
# Moves taken: 41
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . b . . . N P
# . . P . . . P .
# P P . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: b2b3
# Time taken by Move: 1.5961823463439941
# Moves taken: 42
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . p n . p . p .
# p . . p P . N .
# Q . b . . . N P
# . P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b6b5
# Time taken by Move: 1.5533466339111328
# Moves taken: 43
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p p . p P . N .
# Q . b . . . N P
# . P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: a4a3
# Time taken by Move: 1.8342616558074951
# Moves taken: 44
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p p . p P . N .
# . . b . . . N P
# Q P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: b5b4
# Time taken by Move: 2.033590316772461
# Moves taken: 45
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p . . p P . N .
# . p b . . . N P
# Q P P . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: c3b4
# Time taken by Move: 2.197097063064575
# Moves taken: 46
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p . . p P . N .
# . P b . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c4b5
# Time taken by Move: 1.9380114078521729
# Moves taken: 47
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# p b . p P . N .
# . P . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: b4a5
# Time taken by Move: 1.6647918224334717
# Moves taken: 48
# FiveFold False
# . . . r k . . r
# . . q . . p p .
# . . n . p . p .
# P b . p P . N .
# . . . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c7a5
# Time taken by Move: 1.8404593467712402
# Moves taken: 49
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# q b . p P . N .
# . . . . . . N P
# Q P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: a3a5
# Time taken by Move: 1.735846757888794
# Moves taken: 50
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# Q b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# BLACK Turn
# Move in UCI format: c6a5
# Time taken by Move: 1.5619161128997803
# Moves taken: 51
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# n b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . . R R . K .
#
#
# WHITE Turn
# Move in UCI format: d1c1
# Time taken by Move: 1.0949993133544922
# Moves taken: 52
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# n b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: a5c6
# Time taken by Move: 1.3089993000030518
# Moves taken: 53
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# . b . p P . N .
# . . . . . . N P
# . P . . . . P .
# P . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: a2a4
# Time taken by Move: 1.2395944595336914
# Moves taken: 54
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . n . p . p .
# . b . p P . N .
# P . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: c6b4
# Time taken by Move: 1.2953462600708008
# Moves taken: 55
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . b . p P . N .
# P n . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: a4b5
# Time taken by Move: 1.2410125732421875
# Moves taken: 56
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . P . p P . N .
# . n . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: b4d3
# Time taken by Move: 0.9399659633636475
# Moves taken: 57
# FiveFold False
# . . . r k . . r
# . . . . . p p .
# . . . . p . p .
# . P . p P . N .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: g5f7
# Time taken by Move: 1.1704347133636475
# Moves taken: 58
# FiveFold False
# . . . r k . . r
# . . . . . N p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# BLACK Turn
# Move in UCI format: e8f7
# Time taken by Move: 1.081695556640625
# Moves taken: 59
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . n . . P .
# . . . . . P . .
# . . R . R . K .
#
#
# WHITE Turn
# Move in UCI format: c1c3
# Time taken by Move: 1.1264240741729736
# Moves taken: 60
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P R n . . P .
# . . . . . P . .
# . . . . R . K .
#
#
# BLACK Turn
# Move in UCI format: d3e1
# Time taken by Move: 1.2147822380065918
# Moves taken: 61
# FiveFold False
# . . . r . . . r
# . . . . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P R . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# WHITE Turn
# Move in UCI format: c3c7
# Time taken by Move: 0.714998722076416
# Moves taken: 62
# FiveFold False
# . . . r . . . r
# . . R . . k p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# BLACK Turn
# Move in UCI format: f7g8
# Time taken by Move: 0.13969087600708008
# Moves taken: 63
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . . . . p . p .
# . P . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# WHITE Turn
# Move in UCI format: b5b6
# Time taken by Move: 0.5746619701385498
# Moves taken: 64
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . . P .
# . . . . . P . .
# . . . . n . K .
#
#
# BLACK Turn
# Move in UCI format: e1f3
# Time taken by Move: 0.6206414699554443
# Moves taken: 65
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . n P .
# . . . . . P . .
# . . . . . . K .
#
#
# WHITE Turn
# Move in UCI format: g1g2
# Time taken by Move: 0.09302926063537598
# Moves taken: 66
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . . . . N P
# . P . . . n P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3d4
# Time taken by Move: 0.7084541320800781
# Moves taken: 67
# FiveFold False
# . . . r . . k r
# . . R . . . p .
# . P . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b6b7
# Time taken by Move: 0.7229998111724854
# Moves taken: 68
# FiveFold False
# . . . r . . k r
# . P R . . . p .
# . . . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d8b8
# Time taken by Move: 0.7830295562744141
# Moves taken: 69
# FiveFold False
# . r . . . . k r
# . P R . . . p .
# . . . . p . p .
# . . . p P . . .
# . . . n . . N P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g4f6
# Time taken by Move: 0.6136789321899414
# Moves taken: 70
# FiveFold False
# . r . . . . k r
# . P R . . . p .
# . . . . p N p .
# . . . p P . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g7f6
# Time taken by Move: 0.06600666046142578
# Moves taken: 71
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p p p .
# . . . p P . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e5f6
# Time taken by Move: 0.6729934215545654
# Moves taken: 72
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . . . .
# . . . n . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d4f5
# Time taken by Move: 0.6550307273864746
# Moves taken: 73
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . n . .
# . . . . . . . P
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h4h5
# Time taken by Move: 0.6916801929473877
# Moves taken: 74
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P p .
# . . . p . n . P
# . . . . . . . .
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6h5
# Time taken by Move: 0.7675795555114746
# Moves taken: 75
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . p
# . . . . . . . .
# . P . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3b4
# Time taken by Move: 0.6210002899169922
# Moves taken: 76
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . p
# . P . . . . . .
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h5h4
# Time taken by Move: 0.6385376453399658
# Moves taken: 77
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . . . p . n . .
# . P . . . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b4b5
# Time taken by Move: 0.7197706699371338
# Moves taken: 78
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . p . n . .
# . . . . . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d5d4
# Time taken by Move: 0.739931583404541
# Moves taken: 79
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . p . . . p
# . . . . . . P .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g3h4
# Time taken by Move: 0.6706697940826416
# Moves taken: 80
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . p . . . P
# . . . . . . . .
# . . . . . P K .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d4d3
# Time taken by Move: 0.6620290279388428
# Moves taken: 81
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P K .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: g2f1
# Time taken by Move: 0.6703581809997559
# Moves taken: 82
# FiveFold False
# . r . . . . k r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: g8f8
# Time taken by Move: 0.5860004425048828
# Moves taken: 83
# FiveFold False
# . r . . . k . r
# . P R . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: c7c8
# Time taken by Move: 0.6161923408508301
# Moves taken: 84
# FiveFold False
# . r R . . k . r
# . P . . . . . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: f8f7
# Time taken by Move: 0.053998708724975586
# Moves taken: 85
# FiveFold False
# . r R . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: c8h8
# Time taken by Move: 0.7040004730224609
# Moves taken: 86
# FiveFold False
# . r . . . . . R
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# BLACK Turn
# Move in UCI format: b8h8
# Time taken by Move: 0.44099950790405273
# Moves taken: 87
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . . K . .
#
#
# WHITE Turn
# Move in UCI format: f1e1
# Time taken by Move: 0.40783190727233887
# Moves taken: 88
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . . p P . .
# . P . . . n . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . K . . .
#
#
# BLACK Turn
# Move in UCI format: f5d6
# Time taken by Move: 0.43563151359558105
# Moves taken: 89
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . . . P . .
# . . . . K . . .
#
#
# WHITE Turn
# Move in UCI format: e1d2
# Time taken by Move: 0.4083852767944336
# Moves taken: 90
# FiveFold False
# . . . . . . . r
# . P . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . K . P . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d6b7
# Time taken by Move: 0.5670018196105957
# Moves taken: 91
# FiveFold False
# . . . . . . . r
# . n . . . k . .
# . . . . p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . . . .
# . . . K . P . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: f2f3
# Time taken by Move: 0.3539137840270996
# Moves taken: 92
# FiveFold False
# . . . . . . . r
# . n . . . k . .
# . . . . p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b7d6
# Time taken by Move: 0.27967262268066406
# Moves taken: 93
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . . . n p P . .
# . P . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b5b6
# Time taken by Move: 0.31996822357177734
# Moves taken: 94
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . n p P . .
# . . . . . . . .
# . . . . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d6c4
# Time taken by Move: 0.3249986171722412
# Moves taken: 95
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . p . P . .
# . . . K . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2d3
# Time taken by Move: 0.19199872016906738
# Moves taken: 96
# FiveFold False
# . . . . . . . r
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h8c8
# Time taken by Move: 0.3280007839202881
# Moves taken: 97
# FiveFold False
# . . r . . . . .
# . . . . . k . .
# . P . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b6b7
# Time taken by Move: 0.28603076934814453
# Moves taken: 98
# FiveFold False
# . . r . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: c8b8
# Time taken by Move: 0.43000030517578125
# Moves taken: 99
# FiveFold False
# . r . . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . n . . . . P
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3c4
# Time taken by Move: 0.24497008323669434
# Moves taken: 100
# FiveFold False
# . r . . . . . .
# . P . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . K . . . . P
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b8b7
# Time taken by Move: 0.23299908638000488
# Moves taken: 101
# FiveFold False
# . . . . . . . .
# . r . . . k . .
# . . . . p P . .
# . . . . . . . .
# . . K . . . . P
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h4h5
# Time taken by Move: 0.16300225257873535
# Moves taken: 102
# FiveFold False
# . . . . . . . .
# . r . . . k . .
# . . . . p P . .
# . . . . . . . P
# . . K . . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f7f6
# Time taken by Move: 0.1699981689453125
# Moves taken: 103
# FiveFold False
# . . . . . . . .
# . r . . . . . .
# . . . . p k . .
# . . . . . . . P
# . . K . . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4d4
# Time taken by Move: 0.18804240226745605
# Moves taken: 104
# FiveFold False
# . . . . . . . .
# . r . . . . . .
# . . . . p k . .
# . . . . . . . P
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b7b5
# Time taken by Move: 0.2452538013458252
# Moves taken: 105
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . r . . . . . P
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h5h6
# Time taken by Move: 0.19999933242797852
# Moves taken: 106
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p k . P
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f6g6
# Time taken by Move: 0.20200085639953613
# Moves taken: 107
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k P
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: h6h7
# Time taken by Move: 0.21599912643432617
# Moves taken: 108
# FiveFold False
# . . . . . . . .
# . . . . . . . P
# . . . . p . k .
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6h7
# Time taken by Move: 0.33099937438964844
# Moves taken: 109
# FiveFold False
# . . . . . . . .
# . . . . . . . k
# . . . . p . . .
# . r . . . . . .
# . . . K . . . .
# . . . . . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d4d3
# Time taken by Move: 0.1660006046295166
# Moves taken: 110
# FiveFold False
# . . . . . . . .
# . . . . . . . k
# . . . . p . . .
# . r . . . . . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: h7g6
# Time taken by Move: 0.24700021743774414
# Moves taken: 111
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k .
# . r . . . . . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3e3
# Time taken by Move: 0.2976961135864258
# Moves taken: 112
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . k .
# . r . . . . . .
# . . . . . . . .
# . . . . K P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g6f5
# Time taken by Move: 0.23566961288452148
# Moves taken: 113
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . k . .
# . . . . . . . .
# . . . . K P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e3d3
# Time taken by Move: 0.1439990997314453
# Moves taken: 114
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . k . .
# . . . . . . . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f5f4
# Time taken by Move: 0.17800045013427734
# Moves taken: 115
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . . . .
# . . . . . k . .
# . . . K . P . .
# . . . . . . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3e2
# Time taken by Move: 0.17299914360046387
# Moves taken: 116
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . r . . . . . .
# . . . . . k . .
# . . . . . P . .
# . . . . K . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b5b2
# Time taken by Move: 0.1790003776550293
# Moves taken: 117
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . P . .
# . r . . K . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: e2d1
# Time taken by Move: 0.1120002269744873
# Moves taken: 118
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . P . .
# . r . . . . . .
# . . . K . . . .
#
#
# BLACK Turn
# Move in UCI format: f4f3
# Time taken by Move: 0.10300064086914062
# Moves taken: 119
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . r . . . . . .
# . . . K . . . .
#
#
# WHITE Turn
# Move in UCI format: d1e1
# Time taken by Move: 0.06900215148925781
# Moves taken: 120
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . r . . . . . .
# . . . . K . . .
#
#
# BLACK Turn
# Move in UCI format: b2b1
# Time taken by Move: 0.07199668884277344
# Moves taken: 121
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . . . . . .
# . r . . K . . .
#
#
# WHITE Turn
# Move in UCI format: e1d2
# Time taken by Move: 0.03200101852416992
# Moves taken: 122
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e6e5
# Time taken by Move: 0.14699792861938477
# Moves taken: 123
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . . . k . .
# . . . K . . . .
# . r . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2d3
# Time taken by Move: 0.09100079536437988
# Moves taken: 124
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
# . . . K . k . .
# . . . . . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e5e4
# Time taken by Move: 0.1399996280670166
# Moves taken: 125
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . K . k . .
# . . . . . . . .
# . r . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d3c2
# Time taken by Move: 0.16000127792358398
# Moves taken: 126
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
# . . K . . . . .
# . r . . . . . .
#
#
# BLACK Turn
# Move in UCI format: b1a1
# Time taken by Move: 0.13299989700317383
# Moves taken: 127
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
# . . K . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c2c3
# Time taken by Move: 0.12399911880493164
# Moves taken: 128
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . K . . k . .
# . . . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: e4e3
# Time taken by Move: 0.22700023651123047
# Moves taken: 129
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.21699905395507812
# Moves taken: 130
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.16100049018859863
# Moves taken: 131
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.1620011329650879
# Moves taken: 132
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1a1
# Time taken by Move: 0.22899889945983887
# Moves taken: 133
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.22501277923583984
# Moves taken: 134
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.1639857292175293
# Moves taken: 135
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.17399883270263672
# Moves taken: 136
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1a1
# Time taken by Move: 0.23301053047180176
# Moves taken: 137
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# r . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.22998976707458496
# Moves taken: 138
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# r . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a1h1
# Time taken by Move: 0.16501522064208984
# Moves taken: 139
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . p k . .
# . K . . . . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.17398405075073242
# Moves taken: 140
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p k . .
# . . . . . . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: e3e2
# Time taken by Move: 0.22898101806640625
# Moves taken: 141
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . r
#
#
# WHITE Turn
# Move in UCI format: c3b3
# Time taken by Move: 0.3136754035949707
# Moves taken: 142
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . r
#
#
# BLACK Turn
# Move in UCI format: h1d1
# Time taken by Move: 0.29369449615478516
# Moves taken: 143
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . r . . . .
#
#
# WHITE Turn
# Move in UCI format: b3a2
# Time taken by Move: 0.384427547454834
# Moves taken: 144
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# K . . . p . . .
# . . . r . . . .
#
#
# BLACK Turn
# Move in UCI format: d1g1
# Time taken by Move: 0.1711437702178955
# Moves taken: 145
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# K . . . p . . .
# . . . . . . r .
#
#
# WHITE Turn
# Move in UCI format: a2a3
# Time taken by Move: 0.1269688606262207
# Moves taken: 146
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . . k . .
# . . . . p . . .
# . . . . . . r .
#
#
# BLACK Turn
# Move in UCI format: g1g7
# Time taken by Move: 0.19481348991394043
# Moves taken: 147
# FiveFold False
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: a3b3
# Time taken by Move: 0.2069993019104004
# Moves taken: 148
# FiveFold False
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g7g5
# Time taken by Move: 0.3339672088623047
# Moves taken: 149
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3c4
# Time taken by Move: 0.36104798316955566
# Moves taken: 150
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . K . . . . .
# . . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g5a5
# Time taken by Move: 0.30567359924316406
# Moves taken: 151
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . K . . . . .
# . . . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4c3
# Time taken by Move: 0.2555699348449707
# Moves taken: 152
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a5a8
# Time taken by Move: 0.36865234375
# Moves taken: 153
# FiveFold False
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3d2
# Time taken by Move: 0.3447446823120117
# Moves taken: 154
# FiveFold False
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a8a5
# Time taken by Move: 0.21200060844421387
# Moves taken: 155
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . . . K p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: d2c3
# Time taken by Move: 0.20891451835632324
# Moves taken: 156
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a5a7
# Time taken by Move: 0.317690372467041
# Moves taken: 157
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b3
# Time taken by Move: 0.3429996967315674
# Moves taken: 158
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3g4
# Time taken by Move: 0.24197912216186523
# Moves taken: 159
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . K . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b3c4
# Time taken by Move: 0.23399925231933594
# Moves taken: 160
# FiveFold False
# . . . . . . . .
# r . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . k .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: a7d7
# Time taken by Move: 0.3404273986816406
# Moves taken: 161
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . k .
# . . . . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c4c3
# Time taken by Move: 0.21796727180480957
# Moves taken: 162
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . K . . . . .
# . . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g4f3
# Time taken by Move: 0.2680337429046631
# Moves taken: 163
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . k . .
# . . . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: c3b2
# Time taken by Move: 0.20499873161315918
# Moves taken: 164
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . k . .
# . K . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: f3g4
# Time taken by Move: 0.3019707202911377
# Moves taken: 165
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . . .
# . K . . p . . .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b2b1
# Time taken by Move: 0.3634200096130371
# Moves taken: 166
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . . . . .
# . . . . p . . .
# . K . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g4g3
# Time taken by Move: 0.21200203895568848
# Moves taken: 167
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# . . . . p . . .
# . K . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b1a2
# Time taken by Move: 0.2369978427886963
# Moves taken: 168
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . k .
# K . . . p . . .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g3g2
# Time taken by Move: 0.22499847412109375
# Moves taken: 169
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# K . . . p . k .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: a2b2
# Time taken by Move: 0.31299924850463867
# Moves taken: 170
# FiveFold False
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . p . k .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: d7d6
# Time taken by Move: 0.36896419525146484
# Moves taken: 171
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . K . . p . k .
# . . . . . . . .
#
#
# WHITE Turn
# Move in UCI format: b2c3
# Time taken by Move: 0.3619992733001709
# Moves taken: 172
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . p . k .
# . . . . . . . .
#
#
# BLACK Turn
# Move in UCI format: g2f1
# Time taken by Move: 0.27700114250183105
# Moves taken: 173
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: c3b4
# Time taken by Move: 0.18799948692321777
# Moves taken: 174
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . . . . . . . .
# . K . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d6d5
# Time taken by Move: 0.29399991035461426
# Moves taken: 175
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# . K . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: b4a4
# Time taken by Move: 0.19008255004882812
# Moves taken: 176
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . r . . . .
# K . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d5g5
# Time taken by Move: 0.14891910552978516
# Moves taken: 177
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# K . . . . . . .
# . . . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: a4b3
# Time taken by Move: 0.10802912712097168
# Moves taken: 178
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . .
# . K . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: g5b5
# Time taken by Move: 0.2989692687988281
# Moves taken: 179
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . K . . . . . .
# . . . . p . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: b3c2
# Time taken by Move: 0.23799991607666016
# Moves taken: 180
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . p . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: e2e1q
# Time taken by Move: 0.19899964332580566
# Moves taken: 181
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . K . . . . .
# . . . . q k . .
#
#
# WHITE Turn
# Move in UCI format: c2d3
# Time taken by Move: 0.06799960136413574
# Moves taken: 182
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . . . q k . .
#
#
# BLACK Turn
# Move in UCI format: b5b2
# Time taken by Move: 0.23203420639038086
# Moves taken: 183
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . r . . . . . .
# . . . . q k . .
#
#
# WHITE Turn
# Move in UCI format: d3d4
# Time taken by Move: 0.12194538116455078
# Moves taken: 184
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . q k . .
#
#
# BLACK Turn
# Move in UCI format: e1a5
# Time taken by Move: 0.29200148582458496
# Moves taken: 185
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# q . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: d4e4
# Time taken by Move: 0.2938265800476074
# Moves taken: 186
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# q . . . . . . .
# . . . . K . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: a5c3
# Time taken by Move: 0.3616523742675781
# Moves taken: 187
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . K . . .
# . . q . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: e4d5
# Time taken by Move: 0.2230207920074463
# Moves taken: 188
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . q . . . . .
# . r . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b2b6
# Time taken by Move: 0.3340299129486084
# Moves taken: 189
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . K . . . .
# . . . . . . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: d5e4
# Time taken by Move: 0.07896828651428223
# Moves taken: 190
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . .
# . . . . K . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b6b5
# Time taken by Move: 0.35052967071533203
# Moves taken: 191
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . K . . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: e4f4
# Time taken by Move: 0.08171272277832031
# Moves taken: 192
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . K . .
# . . q . . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: c3d3
# Time taken by Move: 0.3190281391143799
# Moves taken: 193
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . K . .
# . . . q . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: f4g4
# Time taken by Move: 0.08697009086608887
# Moves taken: 194
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . K .
# . . . q . . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: d3e3
# Time taken by Move: 0.2955915927886963
# Moves taken: 195
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . K .
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# Move in UCI format: g4h4
# Time taken by Move: 0.09167623519897461
# Moves taken: 196
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . r . . . . . .
# . . . . . . . K
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# BLACK Turn
# Move in UCI format: b5g5
# Time taken by Move: 0.1940314769744873
# Moves taken: 197
# FiveFold False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . r .
# . . . . . . . K
# . . . . q . . .
# . . . . . . . .
# . . . . . k . .
#
#
# WHITE Turn
# GG, checkmate
